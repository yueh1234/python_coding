# %%
import cv2
import numpy as np
import random

# %%
#圖片處理
img = cv2.imread('123.jpg')

kernel1 = np.ones((3,3), np.uint8)
kernel2 = np.ones((3,3), np.uint8)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(img, (15,15), 5)
canny = cv2.Canny(img, 200,250) 
dilate = cv2.dilate(canny, kernel1, iterations=2)
erode = cv2.erode(dilate, kernel1, iterations=2)

# cv2.imshow('img',img)
# cv2.imshow('gray',gray)
# cv2.imshow('blur',blur)
# cv2.imshow('canny',canny)
# cv2.imshow('dilate',dilate)
# cv2.imshow('erode',erode)
# cv2.waitKey(0)

# %%
# 畫圖形

img2 = np.zeros((600,600,3), np.uint8)
cv2.line(img2, (0,0),(400,300), (255,0,0),12)
cv2.rectangle(img2, (0,0), (400,300), (0,0,255),cv2.FILLED)
cv2.circle(img2, (300,400), 300, (0,255,0), cv2.FILLED)
cv2.putText(img2, 'Hello', (300,300), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2)

# cv2.imshow('img2',img2)
# cv2.waitKey(0)

# %%
#顏色檢測

# def empty(v):
#     pass

# img3 = cv2.imread('123.jpg')
# img3 = cv2.resize(img3,(0,0),fx=0.2,fy=0.2)

# hsv = cv2.cvtColor(img3, cv2.COLOR_BGR2HSV)

# cv2.namedWindow('TrackBar')
# cv2.resizeWindow('TrackBar', 640, 320)
# cv2.createTrackbar('Hue Min', 'TrackBar',0,179, empty)
# cv2.createTrackbar('Hue Max', 'TrackBar',179,179, empty)
# cv2.createTrackbar('Sat Min', 'TrackBar',0,255, empty)
# cv2.createTrackbar('Sat Max', 'TrackBar',255,255, empty)
# cv2.createTrackbar('Val Min', 'TrackBar',0,255, empty)
# cv2.createTrackbar('Val Max', 'TrackBar',255,255, empty)

# while True:
#     h_min = cv2.getTrackbarPos('Hue Min', 'TrackBar')
#     h_max = cv2.getTrackbarPos('Hue Max', 'TrackBar')
#     s_min = cv2.getTrackbarPos('Sat Min', 'TrackBar')
#     s_max = cv2.getTrackbarPos('Sat Max', 'TrackBar')
#     v_min = cv2.getTrackbarPos('Val Min', 'TrackBar')
#     v_max = cv2.getTrackbarPos('Val Max', 'TrackBar')
#     # print(h_min,h_max,s_min,s_max,v_min,v_max)
    
#     lower = np.array([h_min,s_min,v_min])
#     upper = np.array([h_max,s_max,v_max])

#     mask = cv2.inRange(hsv,lower,upper)
#     result = cv2.bitwise_and(img3,img3, mask=mask)


    # cv2.imshow('img3',img3)
    # cv2.imshow('hsv',hsv)
    # cv2.imshow('mask',mask)
    # cv2.imshow('result',result)
    # cv2.waitKey(1)

# %%
#邊緣檢測,形狀識別

img4 = cv2.imread('123.jpg')
imgContour = img4.copy()
img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
canny = cv2.Canny(img, 150,200) 
contours, hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

for cnt in contours:
    cv2.drawContours(imgContour, cnt, -1, (255,0,0),4)
    area = cv2.contourArea(cnt)
    if area>500:
        peri = cv2.arcLength(cnt, True)
        vertices = cv2.approxPolyDP(cnt, peri * 0.02, True)
        corners = len(vertices)
        x, y, w, h = cv2.boundingRect(vertices)
        cv2.rectangle(imgContour, (x,y),(x+w,y+h),(0,255,0),4)
        cv2.putText(imgContour, 'trinagle', (x,y-5), cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),2)

# cv2.imshow('img4',img4)
# cv2.imshow('canny',canny)
# cv2.imshow('imgContour',imgContour)
# cv2.waitKey(0)

# %%
# 人臉辨識

# %%
# 虛擬筆

def empty(v):
    pass

cap = cv2.VideoCapture(0)

# while True:
#     ret, frame = cap.read()
#     if ret: 
#         frame = cv2.resize(frame,(0,0),fx=0.4,fy=0.4)
#         cv2.imshow('video', frame)
#     else:
#         break
#     if cv2.waitKey(1) == ord('q'):
#         break

cv2.namedWindow('TrackBar')
cv2.resizeWindow('TrackBar', 640, 320)
cv2.createTrackbar('Hue Min', 'TrackBar',0,179, empty)
cv2.createTrackbar('Hue Max', 'TrackBar',179,179, empty)
cv2.createTrackbar('Sat Min', 'TrackBar',0,255, empty)
cv2.createTrackbar('Sat Max', 'TrackBar',255,255, empty)
cv2.createTrackbar('Val Min', 'TrackBar',0,255, empty)
cv2.createTrackbar('Val Max', 'TrackBar',255,255, empty)

while True:
    h_min = cv2.getTrackbarPos('Hue Min', 'TrackBar')
    h_max = cv2.getTrackbarPos('Hue Max', 'TrackBar')
    s_min = cv2.getTrackbarPos('Sat Min', 'TrackBar')
    s_max = cv2.getTrackbarPos('Sat Max', 'TrackBar')
    v_min = cv2.getTrackbarPos('Val Min', 'TrackBar')
    v_max = cv2.getTrackbarPos('Val Max', 'TrackBar')
    print(h_min,h_max,s_min,s_max,v_min,v_max)
    
    ret, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    lower = np.array([h_min,s_min,v_min])
    upper = np.array([h_max,s_max,v_max])

    mask = cv2.inRange(hsv,lower,upper)
    result = cv2.bitwise_and(frame, frame, mask=mask)


    cv2.imshow('frame',frame)
    # cv2.imshow('hsv',hsv)
    cv2.imshow('mask',mask)
    cv2.imshow('result',result)
    cv2.waitKey(1)
# Out:
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# 0 179 0 255 0 255
# ...
